# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
image = cv2.imread("megan_fox.jpeg",  cv2.IMREAD_COLOR)

# %%
image = cv2.cvtColor(image , cv2.COLOR_BGR2GRAY)

# %%
image = cv2.cvtColor(image , cv2.COLOR_GRAY2RGB)

# %%
print(5)
# Out:
# 5

# %%
print(image.shape)
# Out:
# (3000, 1890, 3)

# %%
plt.imshow(image)
plt.show()
