# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/home/anmol/Desktop/problem datascience/train.csv")

# %%
from IPython.display import display

# %%
display(df)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 11   LP001027    Male     Yes          2      Graduate           NaN
# 12   LP001028    Male     Yes          2      Graduate            No
# ...

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
 mapping = {'Male': 1, 'Female': 0}

df1=df.replace({'Gender':mapping})

# %%
df['Property_Area'].value_counts()
# Out:
# Semiurban    233
# Urban        202
# Rural        179
# Name: Property_Area, dtype: int64

# %%
df['ApplicantIncome'].hist(bins=50)

# %%
plt.show()

# %%
df.boxplot(column='ApplicantIncome')

# %%
plt.show()

# %%
df.boxplot(column='ApplicantIncome', by = 'Education')

# %%
plt.show()

# %%
df['LoanAmount'].hist(bins=50)

# %%
plt.show()

# %%
df.boxplot(column='LoanAmount')

# %%
plt.show()

# %%
df.loc[(df["Gender"]=="Female")&(df["Education"]=="Not Graduate")&(df["Loan_Status"]=="Y"),["Gender","Education","Loan_Status"]]
# Out:
#      Gender     Education Loan_Status
# 50   Female  Not Graduate           Y
# 197  Female  Not Graduate           Y
# 205  Female  Not Graduate           Y
# 279  Female  Not Graduate           Y
# 403  Female  Not Graduate           Y
# 407  Female  Not Graduate           Y
# 439  Female  Not Graduate           Y
# 463  Female  Not Graduate           Y
# 468  Female  Not Graduate           Y
# 480  Female  Not Graduate           Y
# 493  Female  Not Graduate           Y
# 534  Female  Not Graduate           Y
# 544  Female  Not Graduate           Y
# 587  Female  Not Graduate           Y

# %%
def num_missing(x):
    return sum(x.isnull())

# %%
display("Missing values per column:")
df.apply(num_missing, axis=0)
# Out:
# 'Missing values per column:'
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
from scipy.stats import mode

# %%
df1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002     1.0      No          0      Graduate            No
# 1    LP001003     1.0     Yes          1      Graduate            No
# 2    LP001005     1.0     Yes          0      Graduate           Yes
# 3    LP001006     1.0     Yes          0  Not Graduate            No
# 4    LP001008     1.0      No          0      Graduate            No
# 5    LP001011     1.0     Yes          2      Graduate           Yes
# 6    LP001013     1.0     Yes          0  Not Graduate            No
# 7    LP001014     1.0     Yes         3+      Graduate            No
# 8    LP001018     1.0     Yes          2      Graduate            No
# 9    LP001020     1.0     Yes          1      Graduate            No
# 10   LP001024     1.0     Yes          2      Graduate            No
# 11   LP001027     1.0     Yes          2      Graduate           NaN
# 12   LP001028     1.0     Yes          2      Graduate            No
# ...

# %%
mode(df1["Gender"])
# Out:
# ModeResult(mode=array([ 1.]), count=array([489]))

# %%
df1['Gender'].fillna(mode(df1['Gender']).mode[0], inplace=True)

# %%
df1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002     1.0      No          0      Graduate            No
# 1    LP001003     1.0     Yes          1      Graduate            No
# 2    LP001005     1.0     Yes          0      Graduate           Yes
# 3    LP001006     1.0     Yes          0  Not Graduate            No
# 4    LP001008     1.0      No          0      Graduate            No
# 5    LP001011     1.0     Yes          2      Graduate           Yes
# 6    LP001013     1.0     Yes          0  Not Graduate            No
# 7    LP001014     1.0     Yes         3+      Graduate            No
# 8    LP001018     1.0     Yes          2      Graduate            No
# 9    LP001020     1.0     Yes          1      Graduate            No
# 10   LP001024     1.0     Yes          2      Graduate            No
# 11   LP001027     1.0     Yes          2      Graduate           NaN
# 12   LP001028     1.0     Yes          2      Graduate            No
# ...

# %%
mode(df["Married"].astype(str))
# Out:
# /home/anmol/anaconda/lib/python3.6/site-packages/scipy/stats/stats.py:253: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# ModeResult(mode=array(['Yes'], dtype=object), count=array([398]))

# %%
df['Married'].fillna(mode(df['Married'].astype(str)).mode[0], inplace=True)
# Out:
# /home/anmol/anaconda/lib/python3.6/site-packages/scipy/stats/stats.py:253: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)

# %%
mode(df["Dependents"].astype(str))
df['Dependents'].fillna(mode(df['Dependents'].astype(str)).mode[0], inplace=True)
# Out:
# /home/anmol/anaconda/lib/python3.6/site-packages/scipy/stats/stats.py:253: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)

# %%
mode(df["Self_Employed"].astype(str))
df['Self_Employed'].fillna(mode(df['Self_Employed'].astype(str)).mode[0], inplace=True)
# Out:
# /home/anmol/anaconda/lib/python3.6/site-packages/scipy/stats/stats.py:253: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)

# %%
mode(df["Loan_Amount_Term"].astype(str))
df['Loan_Amount_Term'].fillna(mode(df['Loan_Amount_Term']).mode[0], inplace=True)
# Out:
# /home/anmol/anaconda/lib/python3.6/site-packages/scipy/stats/stats.py:253: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)

# %%
np.nanmean(df['LoanAmount'].astype(float))
# Out:
# 146.41216216216216

# %%
mode(df["Credit_History"].astype(str))
df['Credit_History'].fillna(mode(df['Credit_History']).mode[0], inplace=True)
# Out:
# /home/anmol/anaconda/lib/python3.6/site-packages/scipy/stats/stats.py:253: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)

# %%
df['LoanAmount']=df1['LoanAmount']

# %%
impute_grps = df.pivot_table(values=["LoanAmount"], index=["Gender","Married","Self_Employed"], aggfunc=np.mean)
display(impute_grps)
# Out:
#                               LoanAmount
# Gender Married Self_Employed
# Female No      No             114.691176
#                Yes            125.800000
#        Yes     No             134.222222
#                Yes            282.250000
# Male   No      No             130.577982
#                Yes            173.625000
#        Yes     No             151.743333
#                Yes            169.355556

# %%
temp1 = df['Credit_History'].value_counts(ascending=True)

# %%
temp1
# Out:
# 0.0     89
# 1.0    525
# Name: Credit_History, dtype: int64

# %%
temp2 = df.pivot_table(values='Loan_Status',index=['Credit_History'],aggfunc=lambda x: x.map({'Y':1,'N':0}).mean())

# %%
temp2
# Out:
#                 Loan_Status
# Credit_History
# 0.0                0.078652
# 1.0                0.790476

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,4))
ax1 = fig.add_subplot(121)
ax1.set_xlabel('Credit_History')
ax1.set_ylabel('Count of Applicants')
ax1.set_title("Applicants by Credit_History")
temp1.plot(kind='bar')
ax2 = fig.add_subplot(122)
temp2.plot(kind = 'bar')
ax2.set_xlabel('Credit_History')
ax2.set_ylabel('Loan_Status')
ax2.set_title("Probability of getting loan by credit history")

# %%
plt.show()

# %%
impute_grps1 = df.pivot_table(values=["Loan_Status"], index=["Gender","Married","Self_Employed"],
                              aggfunc=lambda x: x.map({'Y':1,'N':0}).mean())
display(impute_grps1)
# Out:
#                               Loan_Status
# Gender Married Self_Employed
# Female No      No                0.637681
#                Yes               0.636364
#        Yes     No                0.785714
#                Yes               0.500000
# Male   No      No                0.631579
#                Yes               0.562500
#        Yes     No                0.717949
#                Yes               0.723404

# %%
temp4=df.pivot_table(values='Loan_Status',index=['Credit_History','Gender'],aggfunc=lambda x: x.map({'Y':1,'N':0}).mean())
display(temp4)
# Out:
#                        Loan_Status
# Credit_History Gender
# 0.0            Female     0.058824
#                Male       0.086957
# 1.0            Female     0.778947
#                Male       0.792857

# %%
temp4.plot(kind='bar')

# %%
plt.show()

# %%
temp5 = pd.crosstab([df['Credit_History'],df['Gender']] , df['Loan_Status'])
temp5.plot(kind='bar', stacked=True, color=['red','blue'], grid=False)

# %% [raw]
# plt.show()

# %%
import numpy as np

# %%
x=np.matrix([[1,2],[3,4]])

# %%
x
# Out:
# matrix([[1, 2],
#         [3, 4]])

# %%
x.sum(axis=1).shape
# Out:
# (2, 1)

# %%
x.shape
# Out:
# (2, 2)

# %%
np.power(x,2)
# Out:
# matrix([[ 1,  4],
#         [ 9, 16]])

# %%
x=lambda a:a+9
x(5)
# Out:
# 14

# %%
x[0,0]
# Out:
# 1

# %%
x[0,1]
# Out:
# 2

# %%
x=[[1,2],[3.5,4]]

# %%
np.mean(x)
# Out:
# 0.0

# %%
x=x-np.mean(x)

# %%
x
# Out:
# array([[-1.625, -0.625],
#        [ 0.875,  1.375]])

# %%
t=np.zeros((3,1))

# %%
t=np.ones((1,3))
b=np.zeros(3)
b.shape
# Out:
# (3,)

# %%
np.matmul(t,b)
# Out:
# array([ 0.])

# %%
X=np.ones((3,1))
X[0]=0

# %%
X.astype(bool)
# Out:
# array([[False],
#        [ True],
#        [ True]], dtype=bool)

# %%
np.ones(5)
# Out:
# array([ 1.,  1.,  1.,  1.,  1.])

# %%
for i in range(0,5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
